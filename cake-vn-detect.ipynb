# %%
#import library
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/banh-vn-data/Banh_vn',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/banh-vn-data/Banh_vn',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 64 images belonging to 4 classes.
# Found 16 images belonging to 4 classes.

# %%
# X_train.shape, y_train.shape,X_test.shape,y_test.shape
train_dataset.classes
train_dataset.class_indices
# Out:
# {'Banh_Hoi': 0, 'Banh_Uot': 1, 'Banh_Xeo': 2, 'Banh_da_lon': 3}

# %%
import numpy as np  #
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM #  :batch... : chuan cua ANN
from keras.models import Sequential #
from tensorflow.keras.utils import to_categorical #  de dam bao do hcinh xac cao 
from keras import callbacks #
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score # thu vien cho do luong

# %%
# Tạo mô hinh
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
# Out:
# 2022-05-20 12:04:24.509975: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D

from keras.layers import Dense, Activation, Flatten


model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 5,596,842
# Trainable params: 5,596,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D

from keras.layers import Dense, Activation, Flatten


model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(4,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 5,598,766
# Trainable params: 5,598,766
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])

# %%
history=model.fit(train_dataset,batch_size=32,epochs=50,verbose=1,validation_data=validation_dataset)
# Out:
# 2022-05-20 12:04:25.191489: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 7/7 [==============================] - 6s 660ms/step - loss: 1.3935 - accuracy: 0.2656 - val_loss: 1.3924 - val_accuracy: 0.2500
# Epoch 2/50
# 7/7 [==============================] - 4s 586ms/step - loss: 1.3904 - accuracy: 0.2344 - val_loss: 1.3880 - val_accuracy: 0.2500
# Epoch 3/50
# 7/7 [==============================] - 4s 590ms/step - loss: 1.3879 - accuracy: 0.2812 - val_loss: 1.3859 - val_accuracy: 0.2500
# Epoch 4/50
# 7/7 [==============================] - 5s 691ms/step - loss: 1.3854 - accuracy: 0.2969 - val_loss: 1.3838 - val_accuracy: 0.3125
# Epoch 5/50
# 7/7 [==============================] - 4s 595ms/step - loss: 1.3764 - accuracy: 0.3438 - val_loss: 1.3796 - val_accuracy: 0.3125
# Epoch 6/50
# 7/7 [==============================] - 4s 597ms/step - loss: 1.3809 - accuracy: 0.3906 - val_loss: 1.3770 - val_accuracy: 0.4375
# Epoch 7/50
# 7/7 [==============================] - 4s 621ms/step - loss: 1.3692 - accuracy: 0.2969 - val_loss: 1.3750 - val_accuracy: 0.3750
# Epoch 8/50
# 7/7 [==============================] - 4s 600ms/step - loss: 1.3677 - accuracy: 0.4062 - val_loss: 1.3712 - val_accuracy: 0.3125
# Epoch 9/50
# 7/7 [==============================] - 4s 599ms/step - loss: 1.3621 - accuracy: 0.3594 - val_loss: 1.3652 - val_accuracy: 0.3125
# Epoch 10/50
# 7/7 [==============================] - 4s 603ms/step - loss: 1.3462 - accuracy: 0.3906 - val_loss: 1.3609 - val_accuracy: 0.3125
# Epoch 11/50
# 7/7 [==============================] - 5s 700ms/step - loss: 1.3316 - accuracy: 0.4531 - val_loss: 1.3708 - val_accuracy: 0.3125
# Epoch 12/50
# 7/7 [==============================] - 4s 578ms/step - loss: 1.3507 - accuracy: 0.4375 - val_loss: 1.3363 - val_accuracy: 0.4375
# Epoch 13/50
# 7/7 [==============================] - 4s 583ms/step - loss: 1.3322 - accuracy: 0.4688 - val_loss: 1.3228 - val_accuracy: 0.5625
# Epoch 14/50
# 7/7 [==============================] - 4s 586ms/step - loss: 1.3288 - accuracy: 0.5000 - val_loss: 1.3134 - val_accuracy: 0.5000
# Epoch 15/50
# 7/7 [==============================] - 4s 579ms/step - loss: 1.3297 - accuracy: 0.4844 - val_loss: 1.3212 - val_accuracy: 0.4375
# Epoch 16/50
# 7/7 [==============================] - 4s 588ms/step - loss: 1.3116 - accuracy: 0.4844 - val_loss: 1.3022 - val_accuracy: 0.5625
# Epoch 17/50
# 7/7 [==============================] - 4s 622ms/step - loss: 1.2907 - accuracy: 0.4844 - val_loss: 1.3056 - val_accuracy: 0.4375
# Epoch 18/50
# 7/7 [==============================] - 5s 681ms/step - loss: 1.3016 - accuracy: 0.4844 - val_loss: 1.2925 - val_accuracy: 0.5000
# Epoch 19/50
# 7/7 [==============================] - 4s 577ms/step - loss: 1.2804 - accuracy: 0.5156 - val_loss: 1.2837 - val_accuracy: 0.5000
# Epoch 20/50
# 7/7 [==============================] - 4s 601ms/step - loss: 1.2592 - accuracy: 0.5312 - val_loss: 1.2770 - val_accuracy: 0.5000
# Epoch 21/50
# 7/7 [==============================] - 4s 587ms/step - loss: 1.2792 - accuracy: 0.5000 - val_loss: 1.2765 - val_accuracy: 0.5000
# Epoch 22/50
# 7/7 [==============================] - 4s 588ms/step - loss: 1.2736 - accuracy: 0.4531 - val_loss: 1.2572 - val_accuracy: 0.5625
# Epoch 23/50
# 7/7 [==============================] - 4s 587ms/step - loss: 1.2576 - accuracy: 0.5312 - val_loss: 1.2520 - val_accuracy: 0.5000
# Epoch 24/50
# 7/7 [==============================] - 5s 700ms/step - loss: 1.2380 - accuracy: 0.5312 - val_loss: 1.2544 - val_accuracy: 0.5000
# Epoch 25/50
# 7/7 [==============================] - 4s 610ms/step - loss: 1.2603 - accuracy: 0.4844 - val_loss: 1.2407 - val_accuracy: 0.5000
# Epoch 26/50
# 7/7 [==============================] - 4s 580ms/step - loss: 1.2339 - accuracy: 0.5156 - val_loss: 1.2386 - val_accuracy: 0.5000
# Epoch 27/50
# 7/7 [==============================] - 4s 591ms/step - loss: 1.2220 - accuracy: 0.5000 - val_loss: 1.2292 - val_accuracy: 0.5000
# Epoch 28/50
# 7/7 [==============================] - 4s 591ms/step - loss: 1.2090 - accuracy: 0.5000 - val_loss: 1.2392 - val_accuracy: 0.5000
# Epoch 29/50
# 7/7 [==============================] - 4s 656ms/step - loss: 1.1995 - accuracy: 0.5312 - val_loss: 1.2088 - val_accuracy: 0.5625
# Epoch 30/50
# 7/7 [==============================] - 4s 587ms/step - loss: 1.1945 - accuracy: 0.5625 - val_loss: 1.2560 - val_accuracy: 0.4375
# Epoch 31/50
# 7/7 [==============================] - 4s 673ms/step - loss: 1.2188 - accuracy: 0.4688 - val_loss: 1.2042 - val_accuracy: 0.5625
# Epoch 32/50
# 7/7 [==============================] - 4s 587ms/step - loss: 1.1781 - accuracy: 0.5312 - val_loss: 1.2144 - val_accuracy: 0.5000
# Epoch 33/50
# 7/7 [==============================] - 4s 593ms/step - loss: 1.1899 - accuracy: 0.5000 - val_loss: 1.1842 - val_accuracy: 0.5000
# Epoch 34/50
# 7/7 [==============================] - 4s 590ms/step - loss: 1.1717 - accuracy: 0.5312 - val_loss: 1.1773 - val_accuracy: 0.5625
# Epoch 35/50
# 7/7 [==============================] - 4s 584ms/step - loss: 1.1596 - accuracy: 0.5312 - val_loss: 1.1763 - val_accuracy: 0.5000
# Epoch 36/50
# 7/7 [==============================] - 4s 586ms/step - loss: 1.1329 - accuracy: 0.5000 - val_loss: 1.1625 - val_accuracy: 0.5000
# Epoch 37/50
# 7/7 [==============================] - 5s 682ms/step - loss: 1.1573 - accuracy: 0.4688 - val_loss: 1.1873 - val_accuracy: 0.5000
# Epoch 38/50
# 7/7 [==============================] - 4s 580ms/step - loss: 1.1356 - accuracy: 0.5156 - val_loss: 1.1529 - val_accuracy: 0.5625
# Epoch 39/50
# 7/7 [==============================] - 4s 573ms/step - loss: 1.1119 - accuracy: 0.5156 - val_loss: 1.1764 - val_accuracy: 0.5000
# Epoch 40/50
# 7/7 [==============================] - 4s 589ms/step - loss: 1.1226 - accuracy: 0.5469 - val_loss: 1.1675 - val_accuracy: 0.5000
# Epoch 41/50
# 7/7 [==============================] - 4s 582ms/step - loss: 1.1101 - accuracy: 0.5156 - val_loss: 1.1190 - val_accuracy: 0.6250
# Epoch 42/50
# 7/7 [==============================] - 4s 594ms/step - loss: 1.0872 - accuracy: 0.5156 - val_loss: 1.1488 - val_accuracy: 0.5000
# Epoch 43/50
# 7/7 [==============================] - 4s 616ms/step - loss: 1.0723 - accuracy: 0.5156 - val_loss: 1.1077 - val_accuracy: 0.6250
# Epoch 44/50
# 7/7 [==============================] - 5s 665ms/step - loss: 1.0604 - accuracy: 0.5000 - val_loss: 1.1522 - val_accuracy: 0.5000
# Epoch 45/50
# 7/7 [==============================] - 4s 585ms/step - loss: 1.0600 - accuracy: 0.5000 - val_loss: 1.0961 - val_accuracy: 0.5625
# Epoch 46/50
# 7/7 [==============================] - 4s 588ms/step - loss: 1.0594 - accuracy: 0.5000 - val_loss: 1.1038 - val_accuracy: 0.5000
# Epoch 47/50
# 7/7 [==============================] - 4s 588ms/step - loss: 1.0322 - accuracy: 0.5000 - val_loss: 1.1144 - val_accuracy: 0.5625
# Epoch 48/50
# 7/7 [==============================] - 4s 583ms/step - loss: 1.0409 - accuracy: 0.4844 - val_loss: 1.0816 - val_accuracy: 0.5625
# Epoch 49/50
# 7/7 [==============================] - 4s 661ms/step - loss: 1.0271 - accuracy: 0.4844 - val_loss: 1.0957 - val_accuracy: 0.5000
# Epoch 50/50
# 7/7 [==============================] - 5s 727ms/step - loss: 1.0181 - accuracy: 0.5312 - val_loss: 1.1397 - val_accuracy: 0.5000

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
#in sai so va do chinh xac
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  1.1396784782409668
# Độ chính xác  0.5

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/banh-xeo/banh_xeo.jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq=np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("banh hoi")
if(kq==1):
    print("Banh uot")
if(kq==2):
    print("Bun xeo")
if(kq==3):
    print("Bun da lon")
# Out:
# banh hoi
